# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">عملیات بیتی (Bitwise Operations) و نقاب‌گذاری تصویر (Masking)</div>
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# %%
circle = np.zeros((400,400),'uint8')
cv2.circle(circle ,(200,200),150,(255,255,255),-1)


rectangle = np.zeros((400,400),'uint8')
cv2.rectangle(rectangle ,(100,50),(300,350),(255,255,255),-1)

plt.figure(figsize=[12,8])
plt.subplot(121);plt.imshow(rectangle ,cmap='gray');plt.title("Rectangle");
plt.subplot(122);plt.imshow(circle,cmap='gray');plt.title("Circle");

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">عملیات بیتی تصویر در OpenCV</div>
# <ul>
#     <li>bitwise_and</li>
#     <li>bitwise_or</li>
#     <li>bitwise_xor</li>
#     <li>bitwise_not</li>
# </ul>

# %%
# Shows only where they intersect
bitwise_and = cv2.bitwise_and( rectangle , circle )

# Shows where either rectangle or circle is 
bitwise_or  = cv2.bitwise_or( rectangle , circle )

# Shows where either exist by itself
bitwise_xor = cv2.bitwise_xor( rectangle , circle )

# Shows everything that isn't part of the rectangle
bitwise_not = cv2.bitwise_not( rectangle )


#show
plt.figure(figsize=[12,6])
plt.subplot(242);plt.imshow(rectangle,cmap='gray');plt.title("Rectangle");
plt.subplot(243);plt.imshow(circle,cmap='gray');plt.title("Circle");
plt.subplot(245);plt.imshow(bitwise_and,cmap='gray');plt.title("And");
plt.subplot(246);plt.imshow(bitwise_or,cmap='gray');plt.title("Or");
plt.subplot(247);plt.imshow(bitwise_xor,cmap='gray');plt.title("Xor");
plt.subplot(248);plt.imshow(bitwise_not,cmap='gray');plt.title("not (Rectangle)");

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">مثال عملی با تصویر رنگی</div>

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt 

img = cv2.imread('./images/MachineVision1.png')
croped_img = img[ 0:500 ,300:800 ]

circle = np.zeros((500,500,3),'uint8')
cv2.circle(circle ,(250,250),250 ,(255,255,255),-1)
out_put = cv2.bitwise_and(croped_img , circle) 

plt.imshow(out_put[...,::-1]);plt.title("Bittwise_And");
